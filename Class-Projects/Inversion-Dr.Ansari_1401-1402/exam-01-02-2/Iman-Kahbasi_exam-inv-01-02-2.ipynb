# %% [markdown]
# <h1><center>Iman Kahbasi</center></h1>
# <b><center>exam-inv-01-02-2</center></b>
# <b><center>1402-02-08</center></b>

# %% [markdown]
# <h2>Import functions</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# <h2>Reading data</h2>

# %%
data = pd.read_excel('data_sarpolzahab.xlsx')
pga = data['PGA (cm/s2)'].values
r_jb = data['R_jb (km)'].values
vs_30 = data['Vs_30 (m/s)'].values

# %% [markdown]
# <h2>Making Sa and Ss parameters in the attenuation formula.</h2>

# %%
msk = vs_30 < 360
print(msk)
# Out:
# [False  True False  True False False  True  True False  True  True  True
#  False False  True  True False False False  True  True  True  True False
#  False False  True False False  True False False False False False False
#   True False False  True False  True False False  True False False  True
#  False False]

# %%
sa = np.zeros(vs_30.size)
ss = np.zeros(vs_30.size)

msk = vs_30 < 360
# sa[msk] = 0
ss[msk] = 1

msk = np.logical_and(360<vs_30, vs_30<750)
sa[msk] = 1
# ss[msk] = 0

# msk = vs_30>750
# sa[msk] = 0
# ss[msk] = 0

# %% [markdown]
# <h2><center>الف: بدست آوردن مقادیر پارامترهای رابطه با فرض عدم وجود خطای مشاهداتی</center></h2>
#
# <h2>Making the G matrix</h2>

# %%
d = np.log10(pga)

G = np.ones((d.size, 4))

# G[:, 0] = 1
G[:, 1] = np.log10(r_jb)
G[:, 2] = ss
G[:, 3] = sa

# %% [markdown]
# <h2>Calculating the model parameters with the least square solution</h2>

# %%
m = np.linalg.inv(G.T @ G) @ G.T @ d
print('Model:', m)
# Out:
# Model: [ 4.6883825  -1.52149415  0.16918781  0.13195647]

# %% [markdown]
# <h2>Estimation of the results that obtain with the estimated model.</h2>

# %%
d_estimation = G @ m

# %%
plt.plot(r_jb, d, label='Observations')
plt.plot(r_jb, d_estimation, label='Estimation')
plt.xlabel('Rjb')
plt.ylabel('Log10(PGA)')
plt.legend()
plt.show()

# %%
residual = d - d_estimation

plt.scatter(r_jb, residual, marker='o', facecolors='none', edgecolors='r')
plt.ylabel('d-Gm')
plt.xlabel('Rjb')
# Out:
# Text(0.5, 0, 'Rjb')

# %% [markdown]
# <h2><center>ب: تخمین میزان انحراف معیار داده‌ها</center></h2>

# %%
# remove Mean from data
G_rm = np.ones((pga.size, 2))
G_rm[:, 1] = r_jb
m_rm = np.linalg.inv(G_rm.T @ G_rm) @ G_rm.T @ pga
pga2 = G_rm @ m_rm
pga_rm = pga - pga2

# %%
sigma = np.sqrt(np.var(pga_rm))
print(f'{sigma=:.2f}')
# Out:
# sigma=89.34

# %%
plt.plot(r_jb, pga_rm, label='Estimation')
plt.xlabel('Rjb')
plt.ylabel('Log10(PGA)')
plt.legend()
plt.show()

# %% [markdown]
# <h2><center>ج: بدست آوردن مقادیر میانگین و انحراف معیار مقادیر مدل به روش شبیه سازی مونته کارلو</center></h2>

# %%
# Model variance
cov_ml2 = (sigma**2) * np.linalg.inv(G.T@G)
cov_ml2 = np.diag(cov_ml2)
print('Model\tCovariance\n')
for ii, _ in enumerate(cov_ml2):
    print(f'm{ii+1}\t{_:.4f}')
# Out:
# Model	Covariance
#
# m1	26120.9901
# m2	5615.0144
# m3	1053.2375
# m4	1100.8318

# %% [markdown]
# <h6>Monte Carlo solution</h6>

# %%
Gw = G /  sigma
dimention = 4
number_of_simulation = 1000
mmc = np.zeros((number_of_simulation, dimention))
mmc_res = np.zeros((number_of_simulation, d_estimation.size))
for ii in range(number_of_simulation):
    # Generate a trial data set of perturbed, weighted data
    ytrial = d + sigma * np.random.randn(d_estimation.size)
    ywtrial = ytrial / sigma
    m_ = np.linalg.inv(Gw.T @ Gw) @ Gw.T @ ywtrial #np.linalg.lstsq(Gw, ywtrial)[0]
    ###
    mmc_res[ii, :] = ytrial - (Gw@m_)
    mmc[ii, :] = m_

# %%
fig, axs = plt.subplots(1, 4, figsize=(9, 3))
scale_labels = ['m', 'm/s', 'm/(s^2)']
for indx in range(4):
    m_ = mmc[:, indx]
    ax = axs[indx]
    ax.hist(m_, bins=20, edgecolor='black')
    ax.set_xlabel('')
    ax.set_title(f'm{indx}')
    mean = np.mean(m_)
    var = np.var(m_)
    print(f'm{indx+1}\t{mean=:.4f}\t{var=:.4f}')
    print('m', indx+1, mean=:.4f}\t{var=:.4f}')
    
plt.tight_layout()
plt.show()
# Out:
# m1	mean=8.0180	var=25038.5925
# m2	mean=-3.0179	var=5495.9005
# m3	mean=-1.2588	var=1065.9914
# m4	mean=2.1577	var=1153.8198

# %% [markdown]
# <h2><center>د: ترسیم مقادیر باقیمانده بدست آمده از مدل بدست آمده در بخش ج  و اظهار نظر در خصوص شکل باقیمانده‌ها</center></h2>

# %%
mmc_res0 = np.hstack(mmc_res)

fig, axs = plt.subplots(1, 2, figsize=(9, 3), sharey=True, gridspec_kw={'width_ratios': [3, 1]})

ax0 = axs[0]
x = np.arange(mmc_res.shape[1])
for ii in range(mmc_res.shape[0]):
#     plt.plot(mmc_res[ii, :])
    ax0.plot(x, mmc_res[ii, :], marker='o')
ax0.set_ylabel('d-Gm')
ax0.set_xlabel('Rjb')

ax1 = axs[1]
ax1.hist(mmc_res0, bins=50, orientation='horizontal')


plt.subplots_adjust(bottom=0.15, wspace=0.01)

# %%
m_mc = np.mean(mmc, axis=0)
print(m_mc)
print(m)
# Out:
# [ 8.0179652  -3.01791212 -1.25881521  2.15774941]
# [ 4.6883825  -1.52149415  0.16918781  0.13195647]

# %%
d_mc = G @ m
residual_mc = d - d_mc

fig, axs = plt.subplots(1, 2, figsize=(9, 3), sharey=True, gridspec_kw={'width_ratios': [3, 1]})
ax0 = axs[0]
ax0.scatter(r_jb, residual, marker='o', facecolors='none', edgecolors='r')
ax0.set_ylabel('d-Gm')
ax0.set_xlabel('Rjb')

ax1 = axs[1]
ax1.hist(residual, bins=20, orientation='horizontal')
plt.subplots_adjust(bottom=0.15, wspace=0.01)
plt.show()

# %% [markdown]
# <center><h1>آیا باقی مانده‌ها دارای توزیع نرمال می‌باشند؟</h1></center>

# %% [markdown]
# بنظر میرسد که توضیع باقی مانده‌ها در حالت کلی برای تمامی حالت مونته کارلو نرمال باشد. اگرچه در مدل نهایی که میانگین حالت‌های مونته کارلو می‌باشد توضیع‌آن نرمال بنظر نمیرسد. و شاید ای موضوع بخاطر فرآوانی داده‌های مورد بررسی باشد.

# %% [markdown]
# <center><h1>آیا مقادیر داده پرت در داده‌ها وجود دارد؟</h1></center>

# %% [markdown]
# حذف هر داده در هر مرحله و محاسبه مدل و ارزیابی آن

# %%
lst_m = np.zeros((d.size, 4))
for ii in range(d.size):
    new_G = np.concatenate((G[:ii, :], G[ii+1:, :]))
    new_d = np.concatenate((d[:ii], d[ii+1:]))
    m = np.linalg.inv(new_G.T @ new_G) @ new_G.T @ new_d
    lst_m[ii, :] = m

# %%
#print(lst_m)

# %%
fig, axs = plt.subplots(1, 4, figsize=(9, 3))
scale_labels = ['m', 'm/s', 'm/(s^2)']
for indx in range(4):
    m_ = lst_m[:, indx]
    ax = axs[indx]
    ax.hist(m_, bins=20, edgecolor='black')
    ax.set_xlabel('')
    ax.set_title(f'm{indx}')
    mean = np.mean(m_)
    var = np.var(m_)
    print(f'm{indx+1}\t{mean=:.4f}\t{var=:.4f}')
    
plt.tight_layout()
plt.show()
# Out:
# m1	mean=4.6875	var=0.0110
# m2	mean=-1.5211	var=0.0024
# m3	mean=0.1693	var=0.0002
# m4	mean=0.1318	var=0.0003

# %%
for indx in range(4):
    m_ = lst_m[:, indx]
    plt.plot(m_)
    plt.show()

# %% [markdown]
# مشاهده می‌شود که با حذف هر داده و محاسبه مدل تغییر متفاوتی در مدل ایجاد نمی‌شود و بنابراین بنظر میرسد داده پرت در بین داده‌ها نباشد.
